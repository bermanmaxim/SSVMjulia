# %% [markdown]
# # Tutorial for svm-struct-julia

# %%
using PyPlot, SSVM1slack  # Julia import of the libraries

# %% [markdown]
# The problem addressed here is presented in the slides of Dr Andrea Vedaldi, author of SVM-struct-matlab. It is a regression problem addressed with a SSVM; the basis functions chosen generate third-order polynomials
#
# http://www.robots.ox.ac.uk/~vedaldi//assets/svm-struct-matlab/tutorial/ssvm-tutorial-handout.pdf, after slide 66.

# %% [markdown]
# ### Problem function definitions

# %%
function lossCB(y, ybar)
  abs(ybar - y)
end

function featureCB(x, y)
  [y,
   y * x,
   y * x^2,
   y * x^3,
   - 0.5 * y^2]
end

function oracleCB(w, x, y)  # loss-augmented inference
  z = w[1] + w[2] * x + w[3] * x.^2 + w[4] * x.^3
    yhat = Float64[]
  if w[5] > 0
    yhat = [z - 1, z + 1] / w[5]
    yhat = max(min(yhat, 1),-1)
  end
    append!(yhat, [-1, 1])   
    augLoss = y_::Vector{Float64} -> abs(y_ - y) + z * y_ - 0.5 * y_.^2 * w[5]
  worse = indmax(augLoss(yhat))
    yhat = yhat[worse]
end

function oracleCB(w, x)    # inference
    z = w[1] + w[2] * x + w[3] * x.^2 + w[4] * x.^3
    y = z / w[5]
end
# Out:
# oracleCB (generic function with 2 methods)

# %% [markdown]
# ###Data generation

# %%
x = collect(linspace(-pi,pi,21))
y = 0.5*sin(x)
y = y + 0.1*randn(size(y));
y_test = y + 0.1*randn(size(y));
xr = collect(linspace(minimum(x), maximum(x), 1024))
yr = collect(linspace(-1,1,1024));

# %% [markdown]
# ### SVM-struct-julia parameters

# %%
param = Dict(
"X" => x,
"Y" => y,
"featureFn" => featureCB,
"lossFn" => lossCB,
"oracleFn" => oracleCB,
"c" => 1,
#"positivity" => [3],  # if one wants to enforce a positivity constraint on a coordinate of w
)

options = Dict(
"quadratic" => :primalqp,
"eps" => 0.001,
"num_passes" => 50,
"cachesize" => 10,
# "incremental" => [50., 80.],
"Xtest" => x,
"Ytest" => y_test,
"verbose" => 4
)
# Out:
# Dict{ASCIIString,Any} with 7 entries:
#   "eps"        => 0.001
#   "cachesize"  => 10
#   "Ytest"      => [0.113614,-0.174868,-0.311085,-0.523333,-0.40152,-0.685972,-0…
#   "Xtest"      => [-3.14159,-2.82743,-2.51327,-2.19911,-1.88496,-1.5708,-1.2566…
#   "verbose"    => 4
#   "num_passes" => 50
#   "quadratic"  => :primalqp

# %% [markdown]
# ### Starting the SSVM

# %%
helper = Dict()
w = SSVM1slack.ssvm_1slack(param, options, helper);
print(helper["iterations"], " iterations; ", helper["inferences"], " augmented inferences")
# Out:
# [SSCM1slack] initializing Convex.jl problem
# [SSCM1slack] begin learning...
# [SSCM1slack] Iter 1: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 1.3206773540076853
# [SSCM1slack] Solving quadratic problem... done! primal: 0.014037424650666435.
# [SSCM1slack] Testing test set... done! mean test loss: 161.52281566021688
# [SSCM1slack] Iter 2: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 2.0822772526737596
# [SSCM1slack] Solving quadratic problem... done! primal: 1.0501849550724731.
# [SSCM1slack] Testing test set... done! mean test loss: 3.6219562654366784
# [SSCM1slack] Iter 3 cache violation 2.2383938230748432: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 1.4724900205389464.
# [SSCM1slack] Testing test set... done! mean test loss: 0.5284118751561765
# [SSCM1slack] Iter 4 cache violation 0.3928889646150006: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.100242647354255.
# [SSCM1slack] Testing test set... done! mean test loss: 0.23013569864678077
# [SSCM1slack] Iter 5 cache violation 0.09438755908647412: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.2079055156988074.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14741447120629694
# [SSCM1slack] Iter 6 cache violation 0.03866076147457473: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.257711115272584.
# [SSCM1slack] Testing test set... done! mean test loss: 0.19417090547321889
# [SSCM1slack] Iter 7 cache violation 0.03322346148244217: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.288274118004795.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16936735424210148
# [SSCM1slack] Iter 8 cache violation 0.005648552327389409: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.2976253700040896.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16536627676620633
# [SSCM1slack] Iter 9 cache violation 0.003719128352931217: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.2978224468878317.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16258325901032733
# [SSCM1slack] Iter 10 cache violation 0.001673939446139856: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.3001531020365564.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16427737920438024
# [SSCM1slack] Iter 11 cache violation 0.0008853513697575904: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.4323124453723684
# [SSCM1slack] Solving quadratic problem... done! primal: 3.0313747623770473.
# [SSCM1slack] Testing test set... done! mean test loss: 0.2843148085429605
# [SSCM1slack] Iter 12 cache violation 0.4062775789636605: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 3.2208790311427498.
# [SSCM1slack] Testing test set... done! mean test loss: 0.24605200819380255
# [SSCM1slack] Iter 13 cache violation 0.47665440747961635: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 5.432743496908794.
# [SSCM1slack] Testing test set... done! mean test loss: 0.3053578611857756
# [SSCM1slack] Iter 14 cache violation 0.286595409781287: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 5.9501958447514385.
# [SSCM1slack] Testing test set... done! mean test loss: 0.22216483327371928
# [SSCM1slack] Iter 15 cache violation 0.18514908867186403: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 6.349966547741846.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1631158699441365
# [SSCM1slack] Iter 16 cache violation 0.06239789350124796: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 6.594050372517739.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15469326338942202
# [SSCM1slack] Iter 17 cache violation 0.06025027779187235: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 6.804990866660473.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16307576765367476
# [SSCM1slack] Iter 18 cache violation 0.04044286777587245: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 6.915165692968524.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1602555772331892
# [SSCM1slack] Iter 19 cache violation 0.02726179551258941: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.008459083186988.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14284018404153218
# [SSCM1slack] Iter 20 cache violation 0.017850153010605545: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.050145772390517.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15218906757892162
# [SSCM1slack] Iter 21 cache violation 0.018092486202889065: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.058542738962584.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1457281012996891
# [SSCM1slack] Iter 22 cache violation 0.006754299169056847: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.076240672173508.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15015972330447178
# [SSCM1slack] Iter 23 cache violation 0.003520049506493759: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.089009512275521.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14426679239879103
# [SSCM1slack] Iter 24 cache violation 0.009041552531234478: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.0925445695082034.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1496728852330826
# [SSCM1slack] Iter 25 cache violation 0.002634366882245812: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.099505191184086.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15263773927451185
# [SSCM1slack] Iter 26 cache violation 0.00256597616296584: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.110578903657668.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1526245595534457
# [SSCM1slack] Iter 27 cache violation 0.0020921858210143363: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.115810200082044.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15093700591431508
# [SSCM1slack] Iter 28 cache violation 0.0011285828658864176: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.117571392587835.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15245566901013183
# [SSCM1slack] Iter 29 cache violation 0.0012990846032810942: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.118784578488716.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15204898551403198
# [SSCM1slack] Iter 30 cache violation -1.6312468781830292e-7: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.23248871574722674
# [SSCM1slack] Solving quadratic problem... done! primal: 8.334093897151947.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13307640664019274
# [SSCM1slack] Iter 31 cache violation 0.031072362694093303: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.392995664181356.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13975596127431256
# [SSCM1slack] Iter 32 cache violation 0.02347371623093203: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.470516163618083.
# [SSCM1slack] Testing test set... done! mean test loss: 0.15197157479337303
# [SSCM1slack] Iter 33 cache violation 0.04891737038917454: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.578673830651338.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14445145229369935
# [SSCM1slack] Iter 34 cache violation 0.027784517351612303: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.640687197088466.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14625842120564497
# [SSCM1slack] Iter 35 cache violation 0.02282187288096338: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.654209970541165.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13229116630177368
# [SSCM1slack] Iter 36 cache violation 0.010374838685078325: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.718494406201923.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1365293774454622
# [SSCM1slack] Iter 37 cache violation 0.009133639772653135: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.719607184552794.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1384830959316369
# [SSCM1slack] Iter 38 cache violation 0.005069397706522538: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.723560322910416.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1417778126059848
# [SSCM1slack] Iter 39 cache violation 0.006364053618820087: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.745550366480066.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13398451411916512
# [SSCM1slack] Iter 40 cache violation 0.004546666576815184: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.753607331396799.

# %% [markdown]
# ### Results

# %%
w
# Out:
# 5-element Array{Float64,1}:
#  -0.0781337
#   0.883285
#   0.0127014
#  -0.0968913
#   2.11064

# %%
z = w[1] + w[2] * xr + w[3] * xr.^2 + w[4] * xr.^3;
F = yr*z' - 0.5 * yr.^2 * ones(size(z))' * w[5]; # scoring function
F_ = F .- maximum(F, 1); # column rescaled
y_fit = oracleCB(w, xr);

# %%
imshow(F_, extent=[minimum(x), maximum(x), -1, 1], origin="lower")
plot(xr, y_fit)
plot(x, y, "o")
xlim([minimum(x), maximum(x)]);
# Out:
# [SSCM1slack] Testing test set... done! mean test loss: 0.13583559070215112
# [SSCM1slack] Iter 41 cache violation 0.002365528974611175: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.775080011692705.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13582516058456914
# [SSCM1slack] Iter 42 cache violation 0.005871845485961591: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.789439165890538.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1412633843439354
# [SSCM1slack] Iter 43 cache violation 0.0015365477748376932: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.792686315817305.
# [SSCM1slack] Testing test set... done! mean test loss: 0.138013759759431
# [SSCM1slack] Iter 44 cache violation 0.001792078654132001: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.793165752212792.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13606616115549897
# [SSCM1slack] Iter 45 cache violation 0.00010295504820334589: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.014521406053849661
# [SSCM1slack] Solving quadratic problem... done! primal: 8.879055122682118.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1405282541949972
# [SSCM1slack] Iter 46 cache violation 0.02070397350702019: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.947811760002475.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1394218810333591
# [SSCM1slack] Iter 47 cache violation 0.01834359412287373: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.961312832969254.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14348327055679647
# [SSCM1slack] Iter 48 cache violation 0.016983542491890824: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.977728717019707.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1296443266228538
# [SSCM1slack] Iter 49 cache violation 0.011248225251443755: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.001423714218692.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13194716798510478
# [SSCM1slack] Iter 50 cache violation 0.00803936478976841: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.045727141904987.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12969582050259992
# [SSCM1slack] Finished!
# 50 iterations; 105 augmented inferences
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ed5bdde50>)

# %% [markdown]
# ###Loss on the test set

# %%
plot(helper["test_iter"][2:end], helper["test_loss"][2:end], "o")
xlabel("iteration")
ylabel("Mean test Loss");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ed59bcd90>)

# %% [markdown]
# ###Time spent for solving the quadratic subproblems (uses warmstarting)

# %%
plot(2:helper["iterations"], helper["time_quadratic"][2:end], "o") # first iteration is much longer, no warm-start
xlabel("Iteration")
ylabel("Time (s)");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ed5b28a50>)

# %% [markdown]
# ### SSVM primal objective

# %%
plot(1:helper["iterations"], helper["primal"], "o")
for i in helper["inference_iter"]
    axvline(x=i, ls="--")
end
xlabel("Iteration")
ylabel("Primal value");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ed5d36650>)

# %% [markdown]
# The vertical dashed lines represent the iterations where a full round of inference is done. The other iterations use constraint caching. One can see a jump in the primal objective when the cached constraints have been exhausted and the algorithm resorts to a new full inference.

# %% [markdown]
# ### Comments

# %% [markdown]
# The current implementation solves the QP primal suproblem, making it easy to add new primal constraints, such as positivity constraints. The SSVM dual does not get computed; doing so could add a certificate of optimality in future improvements.

# %% [markdown]
# Current implementation has the following advantages over SVM-struct-matlab:
# * Constraint caching (reuse full inference results)
# * Parallellization of the inference step (one process per example)
#
# These two points are very beneficial in settings were the inference task takes most of the time.
