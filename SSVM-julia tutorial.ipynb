# %% [markdown]
# # Tutorial for SSVM-julia

# %%
using PyPlot, SSVM1slack  # Julia import of the libraries

# %% [markdown]
# The problem addressed here is presented in the slides of Dr Andrea Vedaldi, author of SVM-struct-matlab. It is a regression problem addressed with a SSVM; the basis functions chosen generate third-order polynomials
#
# http://www.robots.ox.ac.uk/~vedaldi//assets/svm-struct-matlab/tutorial/ssvm-tutorial-handout.pdf, after slide 66.

# %% [markdown]
# ### Problem function definitions

# %%
function lossCB(y, ybar)
  abs(ybar - y)
end

function featureCB(x, y)
  [y,
   y * x,
   y * x^2,
   y * x^3,
   - 0.5 * y^2]
end

function oracleCB(w, x, y)  # loss-augmented inference
  z = w[1] + w[2] * x + w[3] * x.^2 + w[4] * x.^3
    yhat = Float64[]
  if w[5] > 0
    yhat = [z - 1, z + 1] / w[5]
    yhat = max(min(yhat, 1),-1)
  end
    append!(yhat, [-1, 1])   
    augLoss = y_::Vector{Float64} -> abs(y_ - y) + z * y_ - 0.5 * y_.^2 * w[5]
  worse = indmax(augLoss(yhat))
    yhat = yhat[worse]
end

function oracleCB(w, x)    # inference
    z = w[1] + w[2] * x + w[3] * x.^2 + w[4] * x.^3
    y = z / w[5]
end
# Out:
# oracleCB (generic function with 2 methods)

# %% [markdown]
# ###Data generation

# %%
x = collect(linspace(-pi,pi,21))
y = 0.5*sin(x)
y = y + 0.1*randn(size(y));
y_test = y + 0.1*randn(size(y));
xr = collect(linspace(minimum(x), maximum(x), 1024))
yr = collect(linspace(-1,1,1024));

# %% [markdown]
# ### SVM-struct-julia parameters

# %%
param = Dict(
"X" => x,
"Y" => y,
"featureFn" => featureCB,
"lossFn" => lossCB,
"oracleFn" => oracleCB,
"c" => 1,
#"positivity" => [3],  # if one wants to enforce a positivity constraint on a coordinate of w
)

options = Dict(
"quadratic" => :primalqp,
"eps" => 0.001,
"num_passes" => 50,
"cachesize" => 10,
# "incremental" => [50., 80.],
"Xtest" => x,
"Ytest" => y_test,
"verbose" => 4
)
# Out:
# Dict{ASCIIString,Any} with 7 entries:
#   "eps"        => 0.001
#   "cachesize"  => 10
#   "Ytest"      => [0.0108045,-0.186332,-0.445654,-0.477774,-0.507093,-0.592839,…
#   "Xtest"      => [-3.14159,-2.82743,-2.51327,-2.19911,-1.88496,-1.5708,-1.2566…
#   "verbose"    => 4
#   "num_passes" => 50
#   "quadratic"  => :primalqp

# %% [markdown]
# ### Starting the SSVM

# %%
helper = Dict()
w = SSVM1slack.ssvm_1slack(param, options, helper);
print(helper["iterations"], " iterations; ", helper["inferences"], " augmented inferences")
# Out:
# [SSCM1slack] initializing Convex.jl problem
# [SSCM1slack] begin learning...
# [SSCM1slack] Iter 1: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 1.3070929241800666
# [SSCM1slack] Solving quadratic problem... done! primal: 0.03446080051139313.
# [SSCM1slack] Testing test set... done! mean test loss: 101.74365003564736
# [SSCM1slack] Iter 2: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 2.675662960192059
# [SSCM1slack] Solving quadratic problem... done! primal: 1.331212390409495.
# [SSCM1slack] Testing test set... done! mean test loss: 0.7620110552811836
# [SSCM1slack] Iter 3 cache violation 0.4392922153825746: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 1.6252879209166586.
# [SSCM1slack] Testing test set... done! mean test loss: 1.6099734656380102
# [SSCM1slack] Iter 4 cache violation 1.5052873936627231: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.156346997188879.
# [SSCM1slack] Testing test set... done! mean test loss: 0.19321853883842882
# [SSCM1slack] Iter 5 cache violation 0.06888150113773665: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.220893299443012.
# [SSCM1slack] Testing test set... done! mean test loss: 0.16153465327001007
# [SSCM1slack] Iter 6 cache violation 0.06122695563631298: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.261431240003387.
# [SSCM1slack] Testing test set... done! mean test loss: 0.19227461213865946
# [SSCM1slack] Iter 7 cache violation 0.01458314093791904: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.293402899723276.
# [SSCM1slack] Testing test set... done! mean test loss: 0.2253238777132912
# [SSCM1slack] Iter 8 cache violation 0.047462883558873785: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.298566657650064.
# [SSCM1slack] Testing test set... done! mean test loss: 0.19522253154838268
# [SSCM1slack] Iter 9 cache violation 0.015827180306234086: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.3077191119927263.
# [SSCM1slack] Testing test set... done! mean test loss: 0.17645163082118337
# [SSCM1slack] Iter 10 cache violation 0.0030552220370344794: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.308427062368254.
# [SSCM1slack] Testing test set... done! mean test loss: 0.18018764519642924
# [SSCM1slack] Iter 11 cache violation 0.001510414599503434: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 2.3104591109672334.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1774255962350286
# [SSCM1slack] Iter 12 cache violation 0.00016171345100386654: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.43060032457541836
# [SSCM1slack] Solving quadratic problem... done! primal: 3.918607327138264.
# [SSCM1slack] Testing test set... done! mean test loss: 0.4265960559731282
# [SSCM1slack] Iter 13 cache violation 0.6312494435586117: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 4.0313796300591065.
# [SSCM1slack] Testing test set... done! mean test loss: 0.3530130631253036
# [SSCM1slack] Iter 14 cache violation 0.5312188123157924: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 5.374562154539305.
# [SSCM1slack] Testing test set... done! mean test loss: 0.25451147760034964
# [SSCM1slack] Iter 15 cache violation 0.5212493773215584: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 6.563397914269546.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12182400119499362
# [SSCM1slack] Iter 16 cache violation 0.10641604703478603: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.418707016035019.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12006172090483391
# [SSCM1slack] Iter 17 cache violation 0.07589116683555286: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.613982992531972.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1192334845685725
# [SSCM1slack] Iter 18 cache violation 0.05501467875201303: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.750901772034853.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12376538237197571
# [SSCM1slack] Iter 19 cache violation 0.01993124849163755: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.879325847780903.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11659900688742753
# [SSCM1slack] Iter 20 cache violation 0.018515292900723138: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 7.935324032916406.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11595273538665232
# [SSCM1slack] Iter 21 cache violation 0.010788873770641569: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.013513781177158.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12129431816570604
# [SSCM1slack] Iter 22 cache violation 0.012738394215840401: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.032171462503836.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12108412072781097
# [SSCM1slack] Iter 23 cache violation 0.00818754811525653: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.038148754455225.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11863822385549305
# [SSCM1slack] Iter 24 cache violation 0.004933525657066604: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.062895688258788.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12147562460011949
# [SSCM1slack] Iter 25 cache violation 0.006603090227476294: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.071964186011336.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11856641384062117
# [SSCM1slack] Iter 26 cache violation 0.002494238429495449: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.084801895953685.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11755718114892044
# [SSCM1slack] Iter 27 cache violation 0.003001821459063622: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.085923255713013.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11796861664083436
# [SSCM1slack] Iter 28 cache violation -1.7452465506107018e-7: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.1928304122117585
# [SSCM1slack] Solving quadratic problem... done! primal: 9.036353328502504.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12119132867264039
# [SSCM1slack] Iter 29 cache violation 0.03451300796622275: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.059985106611759.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1086072795085842
# [SSCM1slack] Iter 30 cache violation 0.018786144132609872: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.152001294789962.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12345018777868523
# [SSCM1slack] Iter 31 cache violation 0.02969074470104205: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.251509970645262.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11820158047210312
# [SSCM1slack] Iter 32 cache violation 0.023069037332504982: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.288588638138235.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11444615344190158
# [SSCM1slack] Iter 33 cache violation 0.0069350637246539115: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.2926138229832.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11148545334316662
# [SSCM1slack] Iter 34 cache violation 0.007667580900291626: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.322337900360923.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1104238029694312
# [SSCM1slack] Iter 35 cache violation 0.004514529955778834: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.331115730556427.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11413930633018653
# [SSCM1slack] Iter 36 cache violation 0.003662876237515822: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.33705147564887.
# [SSCM1slack] Testing test set... done! mean test loss: 0.10879732376983273
# [SSCM1slack] Iter 37 cache violation 0.0037806938046407446: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.339707494835535.
# [SSCM1slack] Testing test set... done! mean test loss: 0.10893347859892152
# [SSCM1slack] Iter 38 cache violation 0.002098504746056107: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.357688333880036.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11125413408411197
# [SSCM1slack] Iter 39 cache violation 0.001967234774030102: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.364455319438223.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11476846000525809
# [SSCM1slack] Iter 40 cache violation 0.001256994563140823: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.366721628262134.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11256617040182315
# [SSCM1slack] Iter 41 cache violation 0.0007675454554106342: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.014881049359105836
# [SSCM1slack] Solving quadratic problem... done! primal: 9.62146703534865.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1292664352207576
# [SSCM1slack] Iter 42 cache violation 0.011524845156331787: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.648647981665325.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12735069937866683
# [SSCM1slack] Iter 43 cache violation 0.011481234751951452: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.65672611897622.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11745502453756504
# [SSCM1slack] Iter 44 cache violation 0.0029911815400132657: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.657178643170843.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11494792774899208
# [SSCM1slack] Iter 45 cache violation 0.0023931624642636873: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.65877572595268.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11474027017691713
# [SSCM1slack] Iter 46 cache violation 0.0020092539948214916: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.660981437506527.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11497773154981458
# [SSCM1slack] Iter 47 cache violation 0.0016145958019847528: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.66135385700882.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11353682693989965
# [SSCM1slack] Iter 48 cache violation 0.0005176113153577688: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.002610153254777925
# [SSCM1slack] Solving quadratic problem... done! primal: 9.66485608214176.
# [SSCM1slack] Testing test set... done! mean test loss: 0.11529894067413474
# [SSCM1slack] Iter 49 cache violation 0.00036125034764111774: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.0006671505250286369
# [SSCM1slack] Testing test set... done! mean test loss: 0.11529894067413474
#
# 49 iterations; 147 augmented inferences

# %% [markdown]
# ### Results

# %%
w
# Out:
# 5-element Array{Float64,1}:
#  -0.0781337
#   0.883285
#   0.0127014
#  -0.0968913
#   2.11064

# %%
z = w[1] + w[2] * xr + w[3] * xr.^2 + w[4] * xr.^3;
F = yr*z' - 0.5 * yr.^2 * ones(size(z))' * w[5]; # scoring function
F_ = F .- maximum(F, 1); # column rescaled
y_fit = oracleCB(w, xr);

# %%
imshow(F_, extent=[minimum(x), maximum(x), -1, 1], origin="lower")
plot(xr, y_fit)
plot(x, y, "o")
xlim([minimum(x), maximum(x)]);
# Out:
# [SSCM1slack] Testing test set... done! mean test loss: 0.13583559070215112
# [SSCM1slack] Iter 41 cache violation 0.002365528974611175: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.775080011692705.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13582516058456914
# [SSCM1slack] Iter 42 cache violation 0.005871845485961591: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.789439165890538.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1412633843439354
# [SSCM1slack] Iter 43 cache violation 0.0015365477748376932: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.792686315817305.
# [SSCM1slack] Testing test set... done! mean test loss: 0.138013759759431
# [SSCM1slack] Iter 44 cache violation 0.001792078654132001: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.793165752212792.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13606616115549897
# [SSCM1slack] Iter 45 cache violation 0.00010295504820334589: launching inference round (21/21 samples)...
# [SSCM1slack] New violation 0.014521406053849661
# [SSCM1slack] Solving quadratic problem... done! primal: 8.879055122682118.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1405282541949972
# [SSCM1slack] Iter 46 cache violation 0.02070397350702019: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.947811760002475.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1394218810333591
# [SSCM1slack] Iter 47 cache violation 0.01834359412287373: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.961312832969254.
# [SSCM1slack] Testing test set... done! mean test loss: 0.14348327055679647
# [SSCM1slack] Iter 48 cache violation 0.016983542491890824: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 8.977728717019707.
# [SSCM1slack] Testing test set... done! mean test loss: 0.1296443266228538
# [SSCM1slack] Iter 49 cache violation 0.011248225251443755: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.001423714218692.
# [SSCM1slack] Testing test set... done! mean test loss: 0.13194716798510478
# [SSCM1slack] Iter 50 cache violation 0.00803936478976841: using cache...
# [SSCM1slack] Solving quadratic problem... done! primal: 9.045727141904987.
# [SSCM1slack] Testing test set... done! mean test loss: 0.12969582050259992
# [SSCM1slack] Finished!
# 50 iterations; 105 augmented inferences
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f8ed5bdde50>)

# %% [markdown]
# ###Loss on the test set

# %%
plot(helper["test_iter"][2:end], helper["test_loss"][2:end], "o")
xlabel("iteration")
ylabel("Mean test Loss");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f040c84b610>)

# %% [markdown]
# ###Time spent for solving the quadratic subproblems (uses warmstarting)

# %%
plot(2:helper["iterations"]-1, helper["time_quadratic"][2:end], "o") # first iteration is much longer, no warm-start
xlabel("Iteration")
ylabel("Time (s)");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0401316bd0>)

# %% [markdown]
# ### SSVM primal objective

# %%
plot(1:helper["iterations"]-1, helper["primal"], "o")
for i in helper["inference_iter"]
    axvline(x=i, ls="--")
end
xlabel("Iteration")
ylabel("Primal value");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0401154610>)

# %% [markdown]
# The vertical dashed lines represent the iterations where a full round of inference is done. The other iterations use constraint caching. One can see a jump in the primal objective when the cached constraints have been exhausted and the algorithm resorts to a new full inference.

# %% [markdown]
# ### Comments

# %% [markdown]
# The current implementation solves the QP primal suproblem, making it easy to add new primal constraints, such as positivity constraints. The SSVM dual does not get computed; doing so could add a certificate of optimality in future improvements.

# %% [markdown]
# Current implementation has the following advantages over SVM-struct-matlab:
# * Constraint caching (reuse full inference results)
# * Parallellization of the inference step (one process per example)
# * Additional positivity constraints on arbitrary coordinates of $w$
#
# The two first points are very beneficial in settings were the inference task takes most of the time.
